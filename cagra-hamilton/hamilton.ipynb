# %%
! cargo run --release > out.csv
# Out:
#     Finished release [optimized] target(s) in 0.05s
#      Running `target/release/cagra-hamilton`

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("out.csv").set_index("t")

# %%
df.plot()
